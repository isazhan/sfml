# %%
import pandas as pd

# %%
# (1) Используя параметры pandas прочитать красиво пандас 
df = pd.read_csv("UCI_Credit_Card.csv")

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
# (2) выведите, что за типы переменных, сколько пропусков,
# для численных значений посчитайте пару статистик (в свободной форме)
df.dtypes
# Out:
# ID                              int64
# LIMIT_BAL                     float64
# SEX                             int64
# EDUCATION                       int64
# MARRIAGE                        int64
# AGE                             int64
# PAY_0                           int64
# PAY_2                           int64
# PAY_3                           int64
# PAY_4                           int64
# PAY_5                           int64
# PAY_6                           int64
# BILL_AMT1                     float64
# BILL_AMT2                     float64
# BILL_AMT3                     float64
# BILL_AMT4                     float64
# BILL_AMT5                     float64
# BILL_AMT6                     float64
# PAY_AMT1                      float64
# PAY_AMT2                      float64
# PAY_AMT3                      float64
# PAY_AMT4                      float64
# PAY_AMT5                      float64
# PAY_AMT6                      float64
# default.payment.next.month      int64
# ...

# %%
df["AGE"].mean()
# Out:
# 35.4855

# %%
df["LIMIT_BAL"].max()
# Out:
# 1000000.0

# %%
#TODO

# %%
# (3) посчитать число женщин с университетским образованием
# SEX (1 = male; 2 = female). 
# EDUCATION (1 = graduate school; 2 = university; 3 = high school; 4 = others). 

#TODO
df[(df.SEX == 2) & (df.EDUCATION == 2)].shape[0]
# Out:
# 8656

# %%
# (4) Сгрупировать по "default payment next month" и посчитать медиану для всех показателей начинающихся на BILL_ и PAY_
#TODO
df.iloc[:, 6:].groupby(["default.payment.next.month"]).mean()
# Out:
#                                PAY_0     PAY_2     PAY_3     PAY_4     PAY_5  \
# default.payment.next.month
# 0                          -0.211222 -0.301917 -0.316256 -0.355633 -0.389488
# 1                           0.668174  0.458258  0.362116  0.254521  0.167872
#
#                                PAY_6     BILL_AMT1     BILL_AMT2  \
# default.payment.next.month
# 0                          -0.405624  51994.227273  49717.435670
# 1                           0.112116  48509.162297  47283.617842
#
#                                BILL_AMT3     BILL_AMT4     BILL_AMT5  \
# default.payment.next.month
# 0                           47533.365605  43611.165254  40530.445343
# 1                           45181.598855  42036.950573  39540.190476
#
#                                BILL_AMT6     PAY_AMT1     PAY_AMT2  \
# default.payment.next.month
# 0                           39042.268704  6307.337357  6640.465074
# 1                           38271.435503  3397.044153  3388.649638
#
# ...

# %%
# (5) постройте сводную таблицу (pivot table) по SEX, EDUCATION, MARRIAGE

#TODO
df.pivot_table(values="LIMIT_BAL", index=["SEX", "MARRIAGE"], columns=["EDUCATION"])
# Out:
# EDUCATION            0              1              2              3  \
# SEX MARRIAGE
# 1   0              NaN  300000.000000  360000.000000   96666.666667
#     1         205000.0  262485.207101  162101.265823  140143.129771
#     2         215000.0  192085.074060  112442.176871  100847.516779
#     3              NaN  165333.333333   70952.380952   69166.666667
# 2   0              NaN  160000.000000  166000.000000  126562.500000
#     1         135000.0  245319.881890  164180.679785  129387.755102
#     2         267500.0  190821.360153  146840.686275  135674.876847
#     3              NaN  184000.000000   96363.636364   78059.701493
#
# EDUCATION                 4              5              6
# SEX MARRIAGE
# 1   0                   NaN            NaN            NaN
#     1         230000.000000  209916.666667  165714.285714
#     2         173478.260870  107608.695652  146363.636364
#     3         150000.000000  100000.000000            NaN
# ...

# %%
# (6) Создать новый строковый столбец в data frame-е, который:
# принимает значение A, если значение LIMIT_BAL <=10000
# принимает значение B, если значение LIMIT_BAL <=100000 и >10000
# принимает значение C, если значение LIMIT_BAL <=200000 и >100000
# принимает значение D, если значение LIMIT_BAL <=400000 и >200000
# принимает значение E, если значение LIMIT_BAL <=700000 и >400000
# принимает значение F, если значение LIMIT_BAL >700000

#TODO
import numpy as np

conditions = [
    (df["LIMIT_BAL"] <= 10000),
    (df["LIMIT_BAL"] <= 100000) & (df["LIMIT_BAL"] > 10000),
    (df["LIMIT_BAL"] <= 200000) & (df["LIMIT_BAL"] > 100000),
    (df["LIMIT_BAL"] <= 400000) & (df["LIMIT_BAL"] > 200000),
    (df["LIMIT_BAL"] <= 700000) & (df["LIMIT_BAL"] > 400000),
    (df["LIMIT_BAL"] > 700000)]

values = ["A", "B", "C", "D", "E", "F"]

df["limit_code"] = np.select(conditions, values)
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
# %matplotlib inline

# %%
# (7) постироить распределение LIMIT_BAL (гистрограмму)

# %%
#TODO
import matplotlib.pyplot as plt

plt.hist(df["LIMIT_BAL"], bins=100)
plt.show()

# %%
# (8) построить среднее значение кредитного лимита для каждого вида образования 
# и для каждого пола
# график необходимо сделать очень широким (на весь экран)
#TODO
e = df.groupby(["EDUCATION"]).mean()
plt.plot(e["LIMIT_BAL"])

# %%
s = df.groupby(["SEX"]).mean()
plt.plot(s["LIMIT_BAL"])

# %%
# (9) построить зависимость кредитного лимита и образования только для одного из полов

#TODO
l = df.loc[df["SEX"] == 1].groupby(["EDUCATION"]).mean()
plt.plot(l["LIMIT_BAL"])

# %%
# (10) построить большой график (подсказка - используя seaborn) для построения завимисости всех возможных пар параметров
# разным цветом выделить разные значение "default payment next month"
# (но так как столбцов много - картинка может получиться "монструозной")
# (поэкспериментируйте над тем как построить подобное сравнение параметров)
# (подсказка - ответ может состоять из несколькольких графиков)
# (если не выйдет - программа минимум - построить один график со всеми параметрами)
import seaborn as sns

facet_grid = sns.FacetGrid(row='SEX', col='EDUCATION', hue='default.payment.next.month', data=df)
facet_grid.map(sns.scatterplot, 'AGE','LIMIT_BAL')
facet_grid.add_legend()

#TODO
